# %% [markdown]
# ## Problem2

# %% [markdown]
# ECG of different age groups of people has been recorded. The survival time in hours after the operation is given and the event type is denoted by 1 (if dead) and 0 (if alive). Perform survival analysis on the dataset given below and provide your insights in the documentation.

# %%
# pip install lifelines
# import lifelines

import pandas as pd
# Loading the the survival un-employment data
survival_patient = pd.read_excel("ECG_Surv.xlsx")

# %%
survival_patient.head()
# Out:
#    survival_time_hr  alive  age  pericardialeffusion  fractionalshortening  \
# 0              11.0      0   71                    0                 0.260
# 1              19.0      0   72                    0                 0.380
# 2              16.0      0   55                    0                 0.260
# 3              57.0      0   60                    0                 0.253
# 4              19.0      1   57                    0                 0.160
#
#      epss   lvdd  wallmotion-score  wallmotion-index  multi_sensor  name  \
# 0   9.000  4.600              14.0              1.00         1.000  name
# 1   6.000  4.100              14.0              1.70         0.588  name
# 2   4.000  3.420              14.0              1.00         1.000  name
# 3  12.062  4.603              16.0              1.45         0.788  name
# 4  22.000  5.750              18.0              2.25         0.571  name
#
#    group
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
survival_patient
# Out:
#      survival_time_hr  alive  age  pericardialeffusion  fractionalshortening  \
# 0                11.0      0   71                    0                 0.260
# 1                19.0      0   72                    0                 0.380
# 2                16.0      0   55                    0                 0.260
# 3                57.0      0   60                    0                 0.253
# 4                19.0      1   57                    0                 0.160
# ..                ...    ...  ...                  ...                   ...
# 128               7.5      1   64                    0                 0.240
# 129              41.0      0   64                    0                 0.280
# 130              36.0      0   69                    0                 0.200
# 131              22.0      0   57                    0                 0.140
# 132              20.0      0   62                    0                 0.150
#
# ...

# %%
survival_patient.describe()
# Out:
#        survival_time_hr       alive         age  pericardialeffusion  \
# count        133.000000  133.000000  133.000000           133.000000
# mean          21.795338    0.383459   62.413534             0.187970
# std           15.885313    0.488067    9.335601             0.392165
# min            0.030000    0.000000   23.000000             0.000000
# 25%            6.000000    0.000000   57.000000             0.000000
# 50%           22.000000    0.000000   62.000000             0.000000
# 75%           33.000000    1.000000   68.000000             0.000000
# max           57.000000    1.000000   86.000000             1.000000
#
#        fractionalshortening        epss        lvdd  wallmotion-score  \
# count            133.000000  117.000000  121.000000        128.000000
# mean               0.228534   12.164769    4.763157         14.438125
# std                0.135864    7.370159    0.810013          5.018566
# ...

# %%
survival_patient["survival_time_hr"].describe()
# Out:
# count    133.000000
# mean      21.795338
# std       15.885313
# min        0.030000
# 25%        6.000000
# 50%       22.000000
# 75%       33.000000
# max       57.000000
# Name: survival_time_hr, dtype: float64

# %%
# Spell is referring to time 
T = survival_patient.survival_time_hr

# %%
#pip install lifelines
# Out:
# ...
# WARNING: You are using pip version 21.1.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\users\aanand.oradev\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# ...
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4048 sha256=0b924d8a6e7f7fa34460dc9c1678707329e368457923b553634a5949b1f714c9
#   Stored in directory: c:\users\aanand.oradev\appdata\local\pip\cache\wheels\a8\03\64\8557323821d25118c3a2dc1646996f7a962a8970d4b7d22473
# ...
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=8527a9c0cb97dc701a9ed3ceae96c94944d2db1ba27d95157366b90635d2641e
#   Stored in directory: c:\users\aanand.oradev\appdata\local\pip\cache\wheels\2f\a0\d3\4030d9f80e6b3be787f19fc911b8e7aa462986a40ab1e4bb94
# Successfully built autograd-gamma future
# ...

# %%
# Importing the KaplanMeierFitter model to fit the survival analysis
from lifelines import KaplanMeierFitter

# Initiating the KaplanMeierFitter model
kmf = KaplanMeierFitter()

# Fitting KaplanMeierFitter model on Time and Events for death 
kmf.fit(T, event_observed=survival_patient.alive)

# Time-line estimations plot 
kmf.plot()
# Out:
# <AxesSubplot:xlabel='timeline'>

# %%
# Over Multiple groups 
# For each group, here group is scenario
survival_patient.alive.value_counts()
# Out:
# 0    82
# 1    51
# Name: alive, dtype: int64

# %%
survival_patient.group.value_counts()
# Out:
# 2    87
# 1    24
# 3    22
# Name: group, dtype: int64

# %%
# Applying KaplanMeierFitter model on Time and Events for the group 1,2,&3
kmf.fit(T[survival_patient.group==1], survival_patient.alive[survival_patient.group==1], label='1')
ax = kmf.plot()

kmf.fit(T[survival_patient.group==2], survival_patient.alive[survival_patient.group==2], label='2')
ax = kmf.plot()

kmf.fit(T[survival_patient.group==3], survival_patient.alive[survival_patient.group==3], label='3')
ax = kmf.plot()

# %%
Probability of survival in group 3 is higher in the first 30 hrs
Probability of survival in group 2 is higher beyond 30 hrs
# Out:
# <AxesSubplot:xlabel='timeline'>
